# %% [markdown]
# The following is an explanation of the data retrieval process for the project. It can be skipped if you are only interested in the data processing and analysis process.

# %%
#For general data manipulation
import pandas as pd
#package for interacting with the Open Data API
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.sfgov.org", "none")

#First 489000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wg3w-h783", limit=489000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %% [markdown]
# Just to resummarize, the above code line does the following:
#
# 1. We authenticate and gain access to the Socrata Open Data portal using credentials. For people that do not have a APP token to put in the second argument, simply putting none will suffice, but the number of results will be restricted.
#
# 2. This retrieves and converts The first argument is the unique dataset identifier. The second argument specifies the number of results to be retrieved. Note: if you did not input an APP token in the first line
#
# 3. Converts the newly created list of dictionaries into a pandas Dataframe for ease of manipulation
#
# For more information see the documentation regarding the API here: https://dev.socrata.com/foundry/data.sfgov.org/wg3w-h783

# %%
results_df
# Out:
#               incident_datetime            incident_date incident_time  \
# 0       2019-03-05T21:00:00.000  2019-03-05T00:00:00.000         21:00
# 1       2018-12-22T12:00:00.000  2018-12-22T00:00:00.000         12:00
# 2       2018-08-24T17:30:00.000  2018-08-24T00:00:00.000         17:30
# 3       2018-10-20T15:10:00.000  2018-10-20T00:00:00.000         15:10
# 4       2019-06-05T00:36:00.000  2019-06-05T00:00:00.000         00:36
# ...                         ...                      ...           ...
# 488995  2020-07-02T20:30:00.000  2020-07-02T00:00:00.000         20:30
# 488996  2020-12-29T03:16:00.000  2020-12-29T00:00:00.000         03:16
# 488997  2020-07-29T11:24:00.000  2020-07-29T00:00:00.000         11:24
# 488998  2020-10-08T20:00:00.000  2020-10-08T00:00:00.000         20:00
# 488999  2020-07-25T19:00:00.000  2020-07-25T00:00:00.000         19:00
#
#        incident_year incident_day_of_week          report_datetime  \
# ...
