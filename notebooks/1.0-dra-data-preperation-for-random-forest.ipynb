# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
police_data_df = pd.read_csv('C:/Users/DeAndre/Documents/GitHub/SFPD-Police-Data-Project/data/raw/Police_Department_Incident_Reports__2018_to_Present.csv')

# %%
Supervisor_df = pd.read_csv('C:/Users/DeAndre/Documents/GitHub/SFPD-Police-Data-Project/data/processed/Normalized Supervisor District Information.csv')

# %%
PD_df = police_data_df.set_index('Supervisor District').join(Supervisor_df.set_index('Supervisor District'))

# %%
PD_df.head()
# Out:
#                     Incident Datetime Incident Date Incident Time  \
# Supervisor District
# 1.0                  12/16/2018 16:45    12/16/2018         16:45
# 1.0                   11/8/2018 21:54     11/8/2018         21:54
# 1.0                    3/18/2019 9:00     3/18/2019          9:00
# 1.0                   1/18/2018 11:47     1/18/2018         11:47
# 1.0                    2/10/2019 7:40     2/10/2019          7:40
#
#                      Incident Year Incident Day of Week   Report Datetime  \
# Supervisor District
# 1.0                           2018               Sunday  12/16/2018 17:44
# 1.0                           2018             Thursday   11/8/2018 21:55
# 1.0                           2019               Monday   3/18/2019 12:36
# 1.0                           2018             Thursday   1/18/2019 11:59
# 1.0                           2019               Sunday   2/12/2019 12:15
#
#                            Row ID  Incident ID  Incident Number   CAD Number  \
# ...

# %%
PD_df.tail()
# Out:
#                     Incident Datetime Incident Date Incident Time  \
# Supervisor District
# NaN                    12/3/2020 3:04     12/3/2020          3:04
# NaN                    6/7/2020 17:00      6/7/2020         17:00
# NaN                   9/24/2020 18:00     9/24/2020         18:00
# NaN                   7/24/2020 10:00     7/24/2020         10:00
# NaN                    1/4/2021 11:20      1/4/2021         11:20
#
#                      Incident Year Incident Day of Week  Report Datetime  \
# Supervisor District
# NaN                           2020             Thursday   12/3/2020 3:04
# NaN                           2020               Sunday  6/25/2020 20:32
# NaN                           2020             Thursday  9/26/2020 14:20
# NaN                           2020               Friday  7/27/2020 18:05
# NaN                           2021               Monday   1/4/2021 11:21
#
#                            Row ID  Incident ID  Incident Number  CAD Number  \
# ...

# %%
PD_df.shape
# Out:
# (471353, 132)

# %%
PD_df.to_csv('C:/Users/DeAndre/Documents/GitHub/SFPD-Police-Data-Project/data/processed/Joined Data.csv')

# %%
rnd = RandomForestClassifier(n_estimators=100)
